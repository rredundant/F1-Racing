# %%
import requests
import pandas as pd
api='http://ergast.com/api/f1/1970/5/results.json'
resp=requests.get(api).json()
resp.get('MRData').get('RaceTable').get('Races')[0].get('Results')
# Out:
# [{'number': '10',
#   'position': '1',
#   'positionText': '1',
#   'points': '9',
#   'Driver': {'driverId': 'rindt',
#    'url': 'http://en.wikipedia.org/wiki/Jochen_Rindt',
#    'givenName': 'Jochen',
#    'familyName': 'Rindt',
#    'dateOfBirth': '1942-04-18',
#    'nationality': 'Austrian'},
#   'Constructor': {'constructorId': 'team_lotus',
#    'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#    'name': 'Team Lotus',
#    'nationality': 'British'},
#   'grid': '1',
#   'laps': '80',
#   'status': 'Finished',
#   'Time': {'millis': '6643400', 'time': '1:50:43.4'}},
#  {'number': '5',
#   'position': '2',
#   'positionText': '2',
#   'points': '6',
#   'Driver': {'driverId': 'stewart',
#    'url': 'http://en.wikipedia.org/wiki/Jackie_Stewart',
#    'givenName': 'Jackie',
#    'familyName': 'Stewart',
#    'dateOfBirth': '1939-06-11',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'march',
#    'url': 'http://en.wikipedia.org/wiki/March_Engineering',
# ...

# %%
import requests
import pandas as pd
api='http://ergast.com/api/f1/1970/5/drivers.json'
resp=requests.get(api).json()
resp.get('MRData').get('RaceTable').get('Races')[0].get('Results')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-950fc39b1ec0> in <module>()
#       3 api='http://ergast.com/api/f1/1970/5/drivers.json'
#       4 resp=requests.get(api).json()
# ----> 5 resp.get('MRData').get('RaceTable').get('Races')[0].get('Results')
#
# AttributeError: 'NoneType' object has no attribute 'get'
